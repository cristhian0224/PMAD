# %% [markdown]
# # Apilamiento de productos  GeoTiff en pilas de datos de series temporales
#
# Autor: Josef Kellndorfer, Earth Big Data LLC
#
# Adaptado por: Cristhian Forero para la investigación: Diseño de una propuesta de optimización del sistema de alertas tempranas por deforestación para Colombia, caso de estudio “Corazón de la Amazonia”
#
# Este cuaderno describe cómo apilar datos de Sentinel-1 en pilas de datos de series temporales con tablas ráster virtuales. Estos portátiles requieren que GDAL esté instalado y que el ejecutable **gdalbuildvrt** esté en la ruta del sistema.
#
# Algunas suposiciones:
#
# 1) Este cuaderno asume que todos los datos que se apilarán se procesan previamente en la misma proyección, el espacio entre píxeles y las coordenadas de las esquinas son múltiplos sin fracciones del espacio entre píxeles.
#
# 2) Convenciones de nomenclatura: los nombres de archivo geotiff contienen información sobre las tomas de datos, incluida la fecha y la ruta, separados por un guión bajo.
#
# 3) Si se apilan datos con diferentes ubicaciones en las esquinas, la extensión VRT será la extensión máxima de todos los archivos apilados.
#
# SALIDA:
#
# - pilas vrt para cada directorio RTC, para cada ruta y para las pilas combinadas. FINAL: .vrt
# - archivos de fecha correspondientes con entradas "AAAAMMDD" por línea por fecha. FINALIZACIÓN: .fechas

# %%
# Import python modules
import os,sys
import datetime
import glob
import subprocess as sp
import tempfile
import gdal

# %%
# Establezca DryRun en "True" para obtener una lista de los comandos gdalbuildvrt solo sin realizar la calibración
DryRun=True
# Proporcione el directorio raíz donde se almacenan los subdirectorios que contienen los archivos RTC
rootdir='F:/Cristhian/Tesis_capitulo_2/Imagenes_areasdeanalisis_marginaldelaselva/Landsat_Sentinel/2_Norm_con_info/'
# Proporcionar una lista de directorios RTC relativos al rootdir
rtcdirs=['TODAS',]
# Dar una extensión objetivo en coordenadas de proyección
targetextent=None

# %% [markdown]
# ## Defina una función para encontrar todos los archivos en un directorio RTC, extraiga fechas y rutas y llame a gdalbuildvrt

# %%
def make_timeseries_vrt(rootdir,subdir,targetextent=None,prefix='',DryRun=False):
  
  # Obtenga el directorio de trabajo actual y cambie al directorio raíz
    cwd=os.getcwd()
    os.chdir(rootdir)

    imagelist = [x for x in glob.glob(os.path.join(subdir,'*.tif'))]
   # Obtener índice para una fecha válida en la lista separada por '_'
    first=imagelist[0].split('_')
    for i in range(len(first)):
        try:
            datetime.datetime.strptime(first[i],'%Y%m%d')
            idx=i
        except ValueError:
            next
    # Ahora obtén las fechas de todos los archivos
    dates=[x.split('_')[idx] for x in imagelist]
    # Ordenar por fechas y reorganizar la lista de imágenes en consecuencia
    datessorted=dates.copy()
    datessorted.sort()
    indices=[dates.index(x) for x in datessorted]
    imagelistsorted=[imagelist[x] for x in indices]

    # Obtener todos los caminos distintos
    paths=[x.split('_')[idx+1] for x in imagelistsorted]
    distinct_paths=set(paths)

    # We make a directory with vrtnames and have filelists as the entry
    vrtnames={}

    # Crea un vrtname para toda la pila. Usamos el nombre del subdirectorio como raíz para el archivo vrt:
    vrtname=prefix+subdir+'.vrt'
#     vrtnames[vrtname]={'filenames':imagelist, 'dates':dates}

    vrtnames[vrtname]={'filenames':imagelistsorted, 'dates':datessorted}


# Si hay más de una ruta, las agregamos al diccionario
     # para hacer vrtnames y listas correspondientes para archivos y fechas por ruta:
    if len(distinct_paths) > 1:
        for p in distinct_paths:
            # Obtenga el subconjunto de la lista de imágenes que corresponde a esta ruta:
            imagelist_subset=[x for x in imagelistsorted if x.find('_'+p+'_')>-1]
            dates_subset=[x.split('_')[idx] for x in imagelist_subset]
            # El nombre VRT se construye a partir del primer nombre de archivo en la lista rtc sin el 
            vrtname=prefix+subdir+'_'+p+'.vrt'
            vrtnames[vrtname]={'filenames':imagelist_subset, 'dates':dates_subset}

    # Ahora construye las vrts:
    if targetextent==None:
        te=''
    else:
        te='-te '+ targetextent

    for i in vrtnames:
        tfile=tempfile.NamedTemporaryFile(mode='w+',delete=False)
        for j in vrtnames[i]['filenames']:
            tfile.write(j+'\n')
        tfile.close()
        cmd='gdalbuildvrt -separate -allow_projection_difference {} -input_file_list {} -overwrite {}'.format(te,tfile.name,i)
        if not DryRun:
            sp.call(cmd.split())
            # Escribir los archivos de fechas
            datefilename=i.replace('.vrt','.dates')
            with open(datefilename,"w+") as f:
                for j in vrtnames[i]['dates']:
                    f.write(j+'\n')
            # Establecer los nombres de las bandas como fechas
            img_handle=gdal.Open(i)
            for j in range(img_handle.RasterCount):
                x=vrtnames[i]['dates'][j]
                # formatear de YYYYMMDD a YYYY-MM-DD
                date=x[:4]+'-'+x[4:6]+'-'+x[6:8]
                # Establecer los metadatos y la descripción en la fecha
                band=img_handle.GetRasterBand(j+1)
                band.SetMetadataItem("Date",date)
                band.SetDescription(date)
            del img_handle
        else:
            print('DryRun:',end=' ')
        print(cmd)

        os.remove(tfile.name)
    # Cambiar de nuevo al directorio de trabajo original
    os.chdir(cwd)

# %%
## print (imagelist)

# %% [markdown]
# ## Ahora recorra todos los subdirectorios para hacer los vrts
#
# Recorremos todos los subdirectorios (rtcdirs) para generar los vrts. Cambie el prefijo o DryRun para la prueba,
#
#        make_timeseries_vrt(rootdir,i,prefix='test_',DryRun=False)
#        make_timeseries_vrt(rootdir,i,prefix='',DryRun=True)

# %%
for i in rtcdirs:
    make_timeseries_vrt(rootdir,i,prefix='test_',DryRun=False)
# Out:
# gdalbuildvrt -separate -allow_projection_difference  -input_file_list C:\Users\crist\AppData\Local\Temp\tmpe9cc_wz0 -overwrite test_TODAS.vrt

# %% [markdown]
# Ahora podemos inspeccionar esos archivos recién creados con gdal

# %%
os.chdir(rootdir)

# %%
print(gdal.Info('test_NIR.vrt'))
# Out:
# Driver: VRT/Virtual Raster
# Files: test_NIR.vrt
#        NIR\s2_t18nxh_20190101_nir.tif
#        NIR\s2_t18nxh_20190106_nir.tif
#        NIR\lc08_pat759_20190108_nir.tif
#        NIR\s2_t18nxh_20190210_nir.tif
#        NIR\s2_t18nxh_20190215_nir.tif
#        NIR\s2_t18nxh_20190220_nir.tif
#        NIR\lc08_pat759_20190225_nir.tif
#        NIR\s2_t18nxh_20190327_nir.tif
#        NIR\s2_t18nxh_20190401_nir.tif
#        NIR\le07_pat759_20190406_nir.tif
#        NIR\s2_t18nxh_20190426_nir.tif
#        NIR\s2_t18nxh_20190501_nir.tif
#        NIR\s2_t18nxh_20190511_nir.tif
#        NIR\s2_t18nxh_20190526_nir.tif
#        NIR\s2_t18nxh_20190531_nir.tif
#        NIR\s2_t18nxh_20190605_nir.tif
#        NIR\le07_pat759_20190625_nir.tif
#        NIR\s2_t18nxh_20190715_nir.tif
#        NIR\s2_t18nxh_20190809_nir.tif
#        NIR\le07_pat759_20190812_nir.tif
#        NIR\lc08_pat759_20190820_nir.tif
#        NIR\s2_t18nxh_20190824_nir.tif
#        NIR\s2_t18nxh_20190829_nir.tif
#        NIR\s2_t18nxh_20190903_nir.tif
#        NIR\s2_t18nxh_20190908_nir.tif
#        NIR\le07_pat759_20190913_nir.tif
#        NIR\lc08_pat759_20190921_nir.tif
#        NIR\lc08_pat759_20191007_nir.tif
#        NIR\s2_t18nxh_20191013_nir.tif
#        NIR\le07_pat759_20191015_nir.tif
#        NIR\s2_t18nxh_20191028_nir.tif
#        NIR\le07_pat759_20191031_nir.tif
#        NIR\s2_t18nxh_20191107_nir.tif
#        NIR\s2_t18nxh_20191117_nir.tif
#        NIR\s2_t18nxh_20191122_nir.tif
#        NIR\s2_t18nxh_20191127_nir.tif
#        NIR\s2_t18nxh_20191207_nir.tif
#        NIR\s2_t18nxh_20191212_nir.tif
#        NIR\s2_t18nxh_20200101_nir.tif
#        NIR\le07_pat759_20200103_nir.tif
#        NIR\s2_t18nxh_20200106_nir.tif
#        NIR\s2_t18nxh_20200126_nir.tif
#        NIR\lc08_pat759_20200127_nir.tif
#        NIR\s2_t18nxh_20200205_nir.tif
#        NIR\s2_t18nxh_20200210_nir.tif
#        NIR\s2_t18nxh_20200220_nir.tif
#        NIR\s2_t18nxh_20200225_nir.tif
#        NIR\s2_t18nxh_20200301_nir.tif
#        NIR\s2_t18nxh_20200306_nir.tif
#        NIR\s2_t18nxh_20200321_nir.tif
#        NIR\le07_pat759_20200323_nir.tif
#        NIR\s2_t18nxh_20200326_nir.tif
#        NIR\s2_t18nxh_20200415_nir.tif
#        NIR\lc08_pat759_20200416_nir.tif
#        NIR\s2_t18nxh_20200425_nir.tif
#        NIR\s2_t18nxh_20200430_nir.tif
#        NIR\s2_t18nxh_20200505_nir.tif
#        NIR\s2_t18nxh_20200604_nir.tif
#        NIR\s2_t18nxh_20200609_nir.tif
#        NIR\s2_t18nxh_20200714_nir.tif
#        NIR\s2_t18nxh_20200828_nir.tif
#        NIR\s2_t18nxh_20200902_nir.tif
#        NIR\lc08_pat759_20200907_nir.tif
#        NIR\s2_t18nxh_20200912_nir.tif
#        NIR\s2_t18nxh_20200917_nir.tif
#        NIR\s2_t18nxh_20200922_nir.tif
#        NIR\le07_pat759_20201001_nir.tif
#        NIR\lc08_pat759_20201009_nir.tif
#        NIR\s2_t18nxh_20201012_nir.tif
#        NIR\le07_pat759_20201017_nir.tif
#        NIR\s2_t18nxh_20201027_nir.tif
#        NIR\s2_t18nxh_20201106_nir.tif
#        NIR\s2_t18nxh_20201121_nir.tif
#        NIR\s2_t18nxh_20201211_nir.tif
#        NIR\s2_t18nxh_20201216_nir.tif
#        NIR\le07_pat759_20201220_nir.tif
#        NIR\s2_t18nxh_20201221_nir.tif
#        NIR\s2_t18nxh_20201231_nir.tif
#        NIR\s2_t18nxh_20210105_nir.tif
#        NIR\s2_t18nxh_20210115_nir.tif
#        NIR\s2_t18nxh_20210120_nir.tif
#        NIR\s2_t18nxh_20210130_nir.tif
#        NIR\s2_t18nxh_20210214_nir.tif
# Size is 655, 647
# Coordinate System is:
# PROJCRS["WGS 84 / UTM zone 18N",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["UTM zone 18N",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-75,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
#             SCALEUNIT["unity",1],
#             ID["EPSG",8805]],
#         PARAMETER["False easting",500000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["easting",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["northing",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]],
#     ID["EPSG",32618]]
# Data axis to CRS axis mapping: 1,2
# Origin = (649870.991999999969266,233143.406999999686377)
# Pixel Size = (30.000000000000000,-30.000000000000004)
# Corner Coordinates:
# Upper Left  (  649870.992,  233143.407) ( 73d39' 8.52"W,  2d 6'31.41"N)
# Lower Left  (  649870.992,  213733.407) ( 73d39' 9.04"W,  1d55'59.40"N)
# Upper Right (  669520.992,  233143.407) ( 73d28'32.57"W,  2d 6'30.82"N)
# Lower Right (  669520.992,  213733.407) ( 73d28'33.16"W,  1d55'58.86"N)
# Center      (  659695.992,  223438.407) ( 73d33'50.82"W,  2d 1'15.13"N)
# Band 1 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-01-01
#   Metadata:
#     Date=2019-01-01
# Band 2 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-01-06
#   Metadata:
#     Date=2019-01-06
# Band 3 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-01-08
#   Metadata:
#     Date=2019-01-08
# Band 4 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-02-10
#   Metadata:
#     Date=2019-02-10
# Band 5 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-02-15
#   Metadata:
#     Date=2019-02-15
# Band 6 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-02-20
#   Metadata:
#     Date=2019-02-20
# Band 7 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-02-25
#   Metadata:
#     Date=2019-02-25
# Band 8 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-02-25
#   Metadata:
#     Date=2019-02-25
# Band 9 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-03-27
#   Metadata:
#     Date=2019-03-27
# Band 10 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-04-01
#   Metadata:
#     Date=2019-04-01
# Band 11 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-04-06
#   Metadata:
#     Date=2019-04-06
# Band 12 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-04-06
#   Metadata:
#     Date=2019-04-06
# Band 13 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-04-26
#   Metadata:
#     Date=2019-04-26
# Band 14 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-05-01
#   Metadata:
#     Date=2019-05-01
# Band 15 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-05-11
#   Metadata:
#     Date=2019-05-11
# Band 16 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-05-26
#   Metadata:
#     Date=2019-05-26
# Band 17 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-05-31
#   Metadata:
#     Date=2019-05-31
# Band 18 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-06-05
#   Metadata:
#     Date=2019-06-05
# Band 19 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-06-25
#   Metadata:
#     Date=2019-06-25
# Band 20 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-07-15
#   Metadata:
#     Date=2019-07-15
# Band 21 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-08-09
#   Metadata:
#     Date=2019-08-09
# Band 22 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-08-12
#   Metadata:
#     Date=2019-08-12
# Band 23 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-08-20
#   Metadata:
#     Date=2019-08-20
# Band 24 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-08-24
#   Metadata:
#     Date=2019-08-24
# Band 25 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-08-29
#   Metadata:
#     Date=2019-08-29
# Band 26 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-09-03
#   Metadata:
#     Date=2019-09-03
# Band 27 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-09-08
#   Metadata:
#     Date=2019-09-08
# Band 28 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-09-13
#   Metadata:
#     Date=2019-09-13
# Band 29 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-09-21
#   Metadata:
#     Date=2019-09-21
# Band 30 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-10-07
#   Metadata:
#     Date=2019-10-07
# Band 31 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-10-13
#   Metadata:
#     Date=2019-10-13
# Band 32 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-10-15
#   Metadata:
#     Date=2019-10-15
# Band 33 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-10-28
#   Metadata:
#     Date=2019-10-28
# Band 34 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-10-31
#   Metadata:
#     Date=2019-10-31
# Band 35 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-11-07
#   Metadata:
#     Date=2019-11-07
# Band 36 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-11-17
#   Metadata:
#     Date=2019-11-17
# Band 37 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-11-22
#   Metadata:
#     Date=2019-11-22
# Band 38 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-11-27
#   Metadata:
#     Date=2019-11-27
# Band 39 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-12-07
#   Metadata:
#     Date=2019-12-07
# Band 40 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2019-12-12
#   Metadata:
#     Date=2019-12-12
# Band 41 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-01-01
#   Metadata:
#     Date=2020-01-01
# Band 42 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-01-03
#   Metadata:
#     Date=2020-01-03
# Band 43 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-01-06
#   Metadata:
#     Date=2020-01-06
# Band 44 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-01-26
#   Metadata:
#     Date=2020-01-26
# Band 45 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-01-27
#   Metadata:
#     Date=2020-01-27
# Band 46 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-02-05
#   Metadata:
#     Date=2020-02-05
# Band 47 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-02-10
#   Metadata:
#     Date=2020-02-10
# Band 48 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-02-20
#   Metadata:
#     Date=2020-02-20
# Band 49 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-02-25
#   Metadata:
#     Date=2020-02-25
# Band 50 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-03-01
#   Metadata:
#     Date=2020-03-01
# Band 51 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-03-06
#   Metadata:
#     Date=2020-03-06
# Band 52 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-03-21
#   Metadata:
#     Date=2020-03-21
# Band 53 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-03-23
#   Metadata:
#     Date=2020-03-23
# Band 54 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-03-26
#   Metadata:
#     Date=2020-03-26
# Band 55 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-04-15
#   Metadata:
#     Date=2020-04-15
# Band 56 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-04-16
#   Metadata:
#     Date=2020-04-16
# Band 57 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-04-25
#   Metadata:
#     Date=2020-04-25
# Band 58 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-04-30
#   Metadata:
#     Date=2020-04-30
# Band 59 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-05-05
#   Metadata:
#     Date=2020-05-05
# Band 60 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-06-04
#   Metadata:
#     Date=2020-06-04
# Band 61 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-06-09
#   Metadata:
#     Date=2020-06-09
# Band 62 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-07-14
#   Metadata:
#     Date=2020-07-14
# Band 63 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-08-28
#   Metadata:
#     Date=2020-08-28
# Band 64 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-09-02
#   Metadata:
#     Date=2020-09-02
# Band 65 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-09-07
#   Metadata:
#     Date=2020-09-07
# Band 66 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-09-07
#   Metadata:
#     Date=2020-09-07
# Band 67 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-09-12
#   Metadata:
#     Date=2020-09-12
# Band 68 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-09-17
#   Metadata:
#     Date=2020-09-17
# Band 69 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-09-22
#   Metadata:
#     Date=2020-09-22
# Band 70 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-10-01
#   Metadata:
#     Date=2020-10-01
# Band 71 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-10-09
#   Metadata:
#     Date=2020-10-09
# Band 72 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-10-12
#   Metadata:
#     Date=2020-10-12
# Band 73 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-10-17
#   Metadata:
#     Date=2020-10-17
# Band 74 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-10-17
#   Metadata:
#     Date=2020-10-17
# Band 75 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-10-27
#   Metadata:
#     Date=2020-10-27
# Band 76 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-11-06
#   Metadata:
#     Date=2020-11-06
# Band 77 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-11-21
#   Metadata:
#     Date=2020-11-21
# Band 78 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-12-11
#   Metadata:
#     Date=2020-12-11
# Band 79 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-12-16
#   Metadata:
#     Date=2020-12-16
# Band 80 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-12-20
#   Metadata:
#     Date=2020-12-20
# Band 81 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-12-21
#   Metadata:
#     Date=2020-12-21
# Band 82 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2020-12-31
#   Metadata:
#     Date=2020-12-31
# Band 83 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2021-01-05
#   Metadata:
#     Date=2021-01-05
# Band 84 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2021-01-15
#   Metadata:
#     Date=2021-01-15
# Band 85 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2021-01-20
#   Metadata:
#     Date=2021-01-20
# Band 86 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2021-01-30
#   Metadata:
#     Date=2021-01-30
# Band 87 Block=128x128 Type=UInt16, ColorInterp=Undefined
#   Description = 2021-02-14
#   Metadata:
#     Date=2021-02-14

# %%
rootdir
# Out:
# 'F:/Cristhian/Tesis_capitulo_2/Imagenes_areasdeanalisis_marginaldelaselva/Landsat_Sentinel/2_Norm_con_info/'
